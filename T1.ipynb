# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') 

from sklearn.preprocessing import MinMaxScaler 
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('google.csv') 
df.head(10)
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %%
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %%
df = df[['date','open','close']]
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) 
df.set_index('date',drop=True,inplace=True) 
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %%
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
training_size = round(len(df) * 0.75) 
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)):
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data) 
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %%
model = Sequential()

model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 5s 52ms/step - loss: 0.0087 - mean_absolute_error: 0.0654 - val_loss: 0.0160 - val_mean_absolute_error: 0.1021
# Epoch 2/100
# 28/28 [==============================] - 1s 29ms/step - loss: 7.7795e-04 - mean_absolute_error: 0.0221 - val_loss: 0.0037 - val_mean_absolute_error: 0.0475
# Epoch 3/100
# 28/28 [==============================] - 1s 24ms/step - loss: 4.7709e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0030 - val_mean_absolute_error: 0.0421
# Epoch 4/100
# 28/28 [==============================] - 1s 22ms/step - loss: 4.3800e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0031 - val_mean_absolute_error: 0.0422
# Epoch 5/100
# 28/28 [==============================] - 1s 23ms/step - loss: 4.4870e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0037 - val_mean_absolute_error: 0.0471
# Epoch 6/100
# 28/28 [==============================] - 1s 24ms/step - loss: 4.2563e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0035 - val_mean_absolute_error: 0.0459
# Epoch 7/100
# 28/28 [==============================] - 1s 24ms/step - loss: 3.9444e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0048 - val_mean_absolute_error: 0.0551
# Epoch 8/100
# 28/28 [==============================] - 1s 23ms/step - loss: 4.2741e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0026 - val_mean_absolute_error: 0.0382
# Epoch 9/100
# 28/28 [==============================] - 1s 23ms/step - loss: 3.9971e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0046 - val_mean_absolute_error: 0.0531
# Epoch 10/100
# 28/28 [==============================] - 1s 23ms/step - loss: 3.9131e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0064 - val_mean_absolute_error: 0.0653
# Epoch 11/100
# 28/28 [==============================] - 1s 23ms/step - loss: 4.1032e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0044 - val_mean_absolute_error: 0.0513
# Epoch 12/100
# 28/28 [==============================] - 1s 23ms/step - loss: 3.5497e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0045 - val_mean_absolute_error: 0.0522
# Epoch 13/100
# 28/28 [==============================] - 1s 23ms/step - loss: 3.4669e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0058 - val_mean_absolute_error: 0.0609
# Epoch 14/100
# 28/28 [==============================] - 1s 23ms/step - loss: 3.4402e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0071 - val_mean_absolute_error: 0.0688
# Epoch 15/100
# 28/28 [==============================] - 1s 24ms/step - loss: 3.4801e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0039 - val_mean_absolute_error: 0.0472
# Epoch 16/100
# 28/28 [==============================] - 1s 25ms/step - loss: 3.3913e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0047 - val_mean_absolute_error: 0.0532
# Epoch 17/100
# 28/28 [==============================] - 1s 23ms/step - loss: 3.1767e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0070 - val_mean_absolute_error: 0.0675
# Epoch 18/100
# 28/28 [==============================] - 1s 25ms/step - loss: 3.2215e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0054 - val_mean_absolute_error: 0.0573
# Epoch 19/100
# 28/28 [==============================] - 1s 28ms/step - loss: 3.3812e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0049 - val_mean_absolute_error: 0.0548
# Epoch 20/100
# 28/28 [==============================] - 1s 23ms/step - loss: 2.8918e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0054 - val_mean_absolute_error: 0.0574
# Epoch 21/100
# 28/28 [==============================] - 1s 23ms/step - loss: 2.8991e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0058 - val_mean_absolute_error: 0.0605
# Epoch 22/100
# 28/28 [==============================] - 1s 24ms/step - loss: 2.7308e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0044 - val_mean_absolute_error: 0.0507
# Epoch 23/100
# 28/28 [==============================] - 1s 24ms/step - loss: 2.9186e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0050 - val_mean_absolute_error: 0.0552
# Epoch 24/100
# 28/28 [==============================] - 1s 24ms/step - loss: 2.9147e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0031 - val_mean_absolute_error: 0.0411
# Epoch 25/100
# 28/28 [==============================] - 1s 24ms/step - loss: 2.8358e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0075 - val_mean_absolute_error: 0.0705
# Epoch 26/100
# 28/28 [==============================] - 1s 23ms/step - loss: 3.1181e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0073 - val_mean_absolute_error: 0.0699
# Epoch 27/100
# 28/28 [==============================] - 1s 23ms/step - loss: 2.7658e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0033 - val_mean_absolute_error: 0.0423
# Epoch 28/100
# 28/28 [==============================] - 1s 23ms/step - loss: 2.7498e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0039 - val_mean_absolute_error: 0.0469
# Epoch 29/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.6986e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0048 - val_mean_absolute_error: 0.0534
# Epoch 30/100
# 28/28 [==============================] - 1s 23ms/step - loss: 2.5722e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0066 - val_mean_absolute_error: 0.0659
# Epoch 31/100
# 28/28 [==============================] - 1s 23ms/step - loss: 2.6047e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0041 - val_mean_absolute_error: 0.0485
# Epoch 32/100
# 28/28 [==============================] - 1s 23ms/step - loss: 2.5583e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0057 - val_mean_absolute_error: 0.0606
# Epoch 33/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.4253e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0038 - val_mean_absolute_error: 0.0460
# Epoch 34/100
# 28/28 [==============================] - 1s 23ms/step - loss: 2.4151e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0039 - val_mean_absolute_error: 0.0455
# Epoch 35/100
# 28/28 [==============================] - 1s 25ms/step - loss: 2.5183e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0028 - val_mean_absolute_error: 0.0387
# Epoch 36/100
# 28/28 [==============================] - 1s 24ms/step - loss: 2.6455e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0034 - val_mean_absolute_error: 0.0444
# Epoch 37/100
# 28/28 [==============================] - 1s 23ms/step - loss: 2.2185e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0036 - val_mean_absolute_error: 0.0460
# Epoch 38/100
# 28/28 [==============================] - 1s 23ms/step - loss: 2.2412e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0039 - val_mean_absolute_error: 0.0477
# Epoch 39/100
# 28/28 [==============================] - 1s 23ms/step - loss: 2.1770e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0028 - val_mean_absolute_error: 0.0381
# Epoch 40/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.0545e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0029 - val_mean_absolute_error: 0.0392
# Epoch 41/100
# 28/28 [==============================] - 1s 23ms/step - loss: 2.1854e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0023 - val_mean_absolute_error: 0.0329
# Epoch 42/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.2015e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0040 - val_mean_absolute_error: 0.0486
# Epoch 43/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.9658e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0036 - val_mean_absolute_error: 0.0441
# Epoch 44/100
# 28/28 [==============================] - 1s 23ms/step - loss: 2.0241e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0029 - val_mean_absolute_error: 0.0391
# Epoch 45/100
# 28/28 [==============================] - 1s 23ms/step - loss: 2.0738e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0026 - val_mean_absolute_error: 0.0367
# Epoch 46/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.9737e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0046 - val_mean_absolute_error: 0.0536
# Epoch 47/100
# 28/28 [==============================] - 1s 24ms/step - loss: 2.0694e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0047 - val_mean_absolute_error: 0.0529
# Epoch 48/100
# 28/28 [==============================] - 1s 24ms/step - loss: 1.9977e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0047 - val_mean_absolute_error: 0.0525
# Epoch 49/100
# 28/28 [==============================] - 1s 22ms/step - loss: 2.2284e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0041 - val_mean_absolute_error: 0.0496
# Epoch 50/100
# 28/28 [==============================] - 1s 23ms/step - loss: 2.1434e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0022 - val_mean_absolute_error: 0.0331
# Epoch 51/100
# 28/28 [==============================] - 1s 25ms/step - loss: 1.8560e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0036 - val_mean_absolute_error: 0.0456
# Epoch 52/100
# 28/28 [==============================] - 1s 27ms/step - loss: 1.7825e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0015 - val_mean_absolute_error: 0.0278
# Epoch 53/100
# 28/28 [==============================] - 1s 25ms/step - loss: 1.8147e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0019 - val_mean_absolute_error: 0.0310
# Epoch 54/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.7187e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0033 - val_mean_absolute_error: 0.0442
# Epoch 55/100
# 28/28 [==============================] - 1s 26ms/step - loss: 1.5968e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0036 - val_mean_absolute_error: 0.0435
# Epoch 56/100
# 28/28 [==============================] - 1s 27ms/step - loss: 1.6104e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0028 - val_mean_absolute_error: 0.0377
# Epoch 57/100
# 28/28 [==============================] - 1s 27ms/step - loss: 1.6807e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0020 - val_mean_absolute_error: 0.0306
# Epoch 58/100
# 28/28 [==============================] - 1s 27ms/step - loss: 1.6404e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0035 - val_mean_absolute_error: 0.0441
# Epoch 59/100
# 28/28 [==============================] - 1s 27ms/step - loss: 1.5863e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0037 - val_mean_absolute_error: 0.0453
# Epoch 60/100
# 28/28 [==============================] - 1s 27ms/step - loss: 1.3869e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0027 - val_mean_absolute_error: 0.0370
# Epoch 61/100
# 28/28 [==============================] - 1s 26ms/step - loss: 1.5043e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0020 - val_mean_absolute_error: 0.0329
# Epoch 62/100
# 28/28 [==============================] - 1s 28ms/step - loss: 1.5412e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0031 - val_mean_absolute_error: 0.0409
# Epoch 63/100
# 28/28 [==============================] - 1s 27ms/step - loss: 1.6226e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0039 - val_mean_absolute_error: 0.0458
# Epoch 64/100
# 28/28 [==============================] - 1s 27ms/step - loss: 1.4757e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0021 - val_mean_absolute_error: 0.0313
# Epoch 65/100
# 28/28 [==============================] - 1s 27ms/step - loss: 1.5110e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0025 - val_mean_absolute_error: 0.0351
# Epoch 66/100
# 28/28 [==============================] - 1s 27ms/step - loss: 1.6620e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0044 - val_mean_absolute_error: 0.0513
# Epoch 67/100
# 28/28 [==============================] - 1s 28ms/step - loss: 1.4231e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0025 - val_mean_absolute_error: 0.0364
# Epoch 68/100
# 28/28 [==============================] - 1s 27ms/step - loss: 1.5445e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0017 - val_mean_absolute_error: 0.0303
# Epoch 69/100
# 28/28 [==============================] - 1s 26ms/step - loss: 1.3643e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0022 - val_mean_absolute_error: 0.0359
# Epoch 70/100
# 28/28 [==============================] - 1s 26ms/step - loss: 1.2874e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0014 - val_mean_absolute_error: 0.0263
# Epoch 71/100
# 28/28 [==============================] - 1s 26ms/step - loss: 1.3695e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0025 - val_mean_absolute_error: 0.0366
# Epoch 72/100
# 28/28 [==============================] - 1s 26ms/step - loss: 1.4019e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0016 - val_mean_absolute_error: 0.0289
# Epoch 73/100
# 28/28 [==============================] - 1s 26ms/step - loss: 1.3345e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0024 - val_mean_absolute_error: 0.0353
# Epoch 74/100
# 28/28 [==============================] - 1s 26ms/step - loss: 1.3601e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0033 - val_mean_absolute_error: 0.0431
# Epoch 75/100
# 28/28 [==============================] - 1s 27ms/step - loss: 1.2799e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0052 - val_mean_absolute_error: 0.0570
# Epoch 76/100
# 28/28 [==============================] - 1s 26ms/step - loss: 1.2459e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0032 - val_mean_absolute_error: 0.0427
# Epoch 77/100
# 28/28 [==============================] - 1s 27ms/step - loss: 1.2241e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0028 - val_mean_absolute_error: 0.0405
# Epoch 78/100
# 28/28 [==============================] - 1s 29ms/step - loss: 1.2350e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0027 - val_mean_absolute_error: 0.0381
# Epoch 79/100
# 28/28 [==============================] - 1s 28ms/step - loss: 1.2701e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0012 - val_mean_absolute_error: 0.0254
# Epoch 80/100
# 28/28 [==============================] - 1s 28ms/step - loss: 1.1978e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0015 - val_mean_absolute_error: 0.0274
# Epoch 81/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.1682e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0018 - val_mean_absolute_error: 0.0302
# Epoch 82/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.1204e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0021 - val_mean_absolute_error: 0.0345
# Epoch 83/100
# 28/28 [==============================] - 1s 29ms/step - loss: 1.1806e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0020 - val_mean_absolute_error: 0.0330
# Epoch 84/100
# 28/28 [==============================] - 1s 24ms/step - loss: 1.1217e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0019 - val_mean_absolute_error: 0.0317
# Epoch 85/100
# 28/28 [==============================] - 1s 23ms/step - loss: 1.2122e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0015 - val_mean_absolute_error: 0.0280
# Epoch 86/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.2908e-04 - mean_absolute_error: 0.0081 - val_loss: 8.6817e-04 - val_mean_absolute_error: 0.0208
# Epoch 87/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.2043e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0021 - val_mean_absolute_error: 0.0346
# Epoch 88/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.2580e-04 - mean_absolute_error: 0.0080 - val_loss: 9.6296e-04 - val_mean_absolute_error: 0.0215
# Epoch 89/100
# 28/28 [==============================] - 1s 23ms/step - loss: 1.2111e-04 - mean_absolute_error: 0.0078 - val_loss: 6.4061e-04 - val_mean_absolute_error: 0.0186
# Epoch 90/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.2224e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0012 - val_mean_absolute_error: 0.0245
# Epoch 91/100
# 28/28 [==============================] - 1s 21ms/step - loss: 1.0693e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0010 - val_mean_absolute_error: 0.0228
# Epoch 92/100
# 28/28 [==============================] - 1s 22ms/step - loss: 1.0762e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0018 - val_mean_absolute_error: 0.0315
# Epoch 93/100
# 28/28 [==============================] - 1s 23ms/step - loss: 1.0924e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0013 - val_mean_absolute_error: 0.0261
# Epoch 94/100
# 28/28 [==============================] - 1s 23ms/step - loss: 1.0267e-04 - mean_absolute_error: 0.0072 - val_loss: 6.2091e-04 - val_mean_absolute_error: 0.0179
# Epoch 95/100
# 28/28 [==============================] - 1s 25ms/step - loss: 1.0271e-04 - mean_absolute_error: 0.0071 - val_loss: 0.0012 - val_mean_absolute_error: 0.0254
# Epoch 96/100
# 28/28 [==============================] - 1s 29ms/step - loss: 1.0541e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0021 - val_mean_absolute_error: 0.0360
# Epoch 97/100
# 28/28 [==============================] - 1s 25ms/step - loss: 1.3052e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0011 - val_mean_absolute_error: 0.0227
# Epoch 98/100
# 28/28 [==============================] - 1s 28ms/step - loss: 1.0024e-04 - mean_absolute_error: 0.0072 - val_loss: 0.0010 - val_mean_absolute_error: 0.0234
# Epoch 99/100
# 28/28 [==============================] - 1s 25ms/step - loss: 1.0557e-04 - mean_absolute_error: 0.0072 - val_loss: 0.0014 - val_mean_absolute_error: 0.0285
# Epoch 100/100
# 28/28 [==============================] - 1s 22ms/step - loss: 9.7686e-05 - mean_absolute_error: 0.0071 - val_loss: 0.0014 - val_mean_absolute_error: 0.0287

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 1s 9ms/step
# array([[0.39719716, 0.40088534],
#        [0.3968201 , 0.40015587],
#        [0.39403608, 0.39715108],
#        [0.3985167 , 0.40224263],
#        [0.40237346, 0.4063172 ]], dtype=float32)

# %%
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1407.3717, 1411.2369],
#        [1406.6727, 1409.8849],
#        [1401.5114, 1404.3159],
#        [1409.8181, 1413.7523],
#        [1416.9681, 1421.304 ]], dtype=float32)

# %%
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1407.371704      1411.236938
# 2020-05-28  1396.86  1416.73     1406.672729      1409.884888
# 2020-05-29  1416.94  1428.92     1401.511353      1404.315918
# 2020-06-01  1418.39  1431.82     1409.818115      1413.752319
# 2020-06-02  1430.55  1439.22     1416.968140      1421.303955

# %%
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %%
 

df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
                                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11472\1009832048.py in ?()
# ----> 1 df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
#       2                                         index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
#       3 df_merge['2021-06-09':'2021-06-16']
#
# c:\Users\DK\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step

# %%
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()
